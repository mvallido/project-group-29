# %% [markdown]
# # Michael Vallido

# %% [markdown]
# ## Research question/interests
#
# Due to Covid-19's impact throughout the last year and a half, I think it would be interesting to take a deeper look into how Covid-19 has influenced peoples mental health among all of the United States.

# %%
import pandas as pd
df = pd.read_csv("../data/raw/Indicators_of_Anxiety_or_Depression_Based_on_Reported_Frequency_of_Symptoms_During_Last_7_Days.csv")
df
# Out:
#                                               Indicator              Group  \
# 0                       Symptoms of Depressive Disorder  National Estimate
# 1                       Symptoms of Depressive Disorder             By Age
# 2                       Symptoms of Depressive Disorder             By Age
# 3                       Symptoms of Depressive Disorder             By Age
# 4                       Symptoms of Depressive Disorder             By Age
# ...                                                 ...                ...
# 8365  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 8366  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 8367  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 8368  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 8369  Symptoms of Anxiety Disorder or Depressive Dis...           By State
#
# ...

# %% [markdown]
# # MILESTONE 3: Task 1, 2, and 3

# %% [markdown]
# ## Task 1 & 2

# %% [markdown]
# ## Loading Data

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Retrieve csv data
df = pd.read_csv("../data/raw/Indicators_of_Anxiety_or_Depression_Based_on_Reported_Frequency_of_Symptoms_During_Last_7_Days.csv")


raw = df.drop(columns=['Phase','Time Period','Subgroup','Time Period Start Date','Time Period Start Date','Time Period End Date','Low CI','High CI','Quartile Range'])

# %% [markdown]
# ## Cleaning Data
#
# Cleaning the dataframe so it only contains the following:
# - Indicator: Symptoms of Depressive Disorder
# - Group: By State
# - Time Period Label: Sep 15 - Sep 27, 2021
# - Percentage
# - Confidence Interval

# %%
raw.shape
# Out:
# (8370, 6)

# %%
raw.isnull().sum()
# Out:
# Indicator                0
# Group                    0
# State                    0
# Time Period Label        0
# Value                  234
# Confidence Interval    234
# dtype: int64

# %%
raw.dropna()
# Out:
#                                               Indicator              Group  \
# 0                       Symptoms of Depressive Disorder  National Estimate
# 1                       Symptoms of Depressive Disorder             By Age
# 2                       Symptoms of Depressive Disorder             By Age
# 3                       Symptoms of Depressive Disorder             By Age
# 4                       Symptoms of Depressive Disorder             By Age
# ...                                                 ...                ...
# 8365  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 8366  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 8367  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 8368  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 8369  Symptoms of Anxiety Disorder or Depressive Dis...           By State
#
# ...

# %%
raw.drop(raw[raw["Indicator"] != "Symptoms of Depressive Disorder"].index, inplace=True)
raw.drop(raw[raw["Group"] != "By State"].index, inplace=True)
raw.drop(raw[raw["Time Period Label"] != "Sep 15 - Sep 27, 2021"].index, inplace=True)
raw = raw.rename(columns={"Value":"Percentage"})

# %%
df_clean = raw.reset_index(drop=True)
df_clean
# Out:
#                           Indicator     Group                 State  \
# 0   Symptoms of Depressive Disorder  By State               Alabama
# 1   Symptoms of Depressive Disorder  By State                Alaska
# 2   Symptoms of Depressive Disorder  By State               Arizona
# 3   Symptoms of Depressive Disorder  By State              Arkansas
# 4   Symptoms of Depressive Disorder  By State            California
# 5   Symptoms of Depressive Disorder  By State              Colorado
# 6   Symptoms of Depressive Disorder  By State           Connecticut
# 7   Symptoms of Depressive Disorder  By State              Delaware
# 8   Symptoms of Depressive Disorder  By State  District of Columbia
# 9   Symptoms of Depressive Disorder  By State               Florida
# 10  Symptoms of Depressive Disorder  By State               Georgia
# 11  Symptoms of Depressive Disorder  By State                Hawaii
# 12  Symptoms of Depressive Disorder  By State                 Idaho
# ...

# %%
df_clean.to_csv('mvallido_cleanedData.csv',index=False)

# %% [markdown]
# ## EDA

# %%
df_cleaned = pd.read_csv("../data/processed/mvallido_cleanedData.csv")
df_cleaned
# Out:
#                           Indicator     Group                 State  \
# 0   Symptoms of Depressive Disorder  By State               Alabama
# 1   Symptoms of Depressive Disorder  By State                Alaska
# 2   Symptoms of Depressive Disorder  By State               Arizona
# 3   Symptoms of Depressive Disorder  By State              Arkansas
# 4   Symptoms of Depressive Disorder  By State            California
# 5   Symptoms of Depressive Disorder  By State              Colorado
# 6   Symptoms of Depressive Disorder  By State           Connecticut
# 7   Symptoms of Depressive Disorder  By State              Delaware
# 8   Symptoms of Depressive Disorder  By State  District of Columbia
# 9   Symptoms of Depressive Disorder  By State               Florida
# 10  Symptoms of Depressive Disorder  By State               Georgia
# 11  Symptoms of Depressive Disorder  By State                Hawaii
# 12  Symptoms of Depressive Disorder  By State                 Idaho
# ...

# %%
df_cleaned.dtypes
# Out:
# Indicator               object
# Group                   object
# State                   object
# Time Period Label       object
# Value                  float64
# Confidence Interval     object
# dtype: object

# %%
df_cleaned.describe()
# Out:
#            Value
# count  51.000000
# mean   22.009804
# std     4.222949
# min    15.300000
# 25%    18.350000
# 50%    21.300000
# 75%    25.450000
# max    30.600000

# %% [markdown]
# ## Visualizations

# %%
sns.set(rc = {'figure.figsize':(75,15)})
sns.barplot(x="Percentage",y="State",data=df_cleaned)
# Out:
# <AxesSubplot:xlabel='Percentage', ylabel='State'>

# %%
test = df_cleaned.pivot_table(index='State',columns=['Confidence Interval'],values='Percentage')
test.fillna(0)

sns.heatmap(test,cmap='Blues')
# Out:
# <AxesSubplot:xlabel='Confidence Interval', ylabel='State'>

# %% [markdown]
# ## Task 3

# %% [markdown]
# ### Step 1 - Method Chaining

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# There's probably a better way to method chain this process for the specific outcome I want, but this does clean up 
# the code I had previously a decent amount

df = (
    pd
    .read_csv("../data/raw/Indicators_of_Anxiety_or_Depression_Based_on_Reported_Frequency_of_Symptoms_During_Last_7_Days.csv")
    .drop(columns=['Phase','Time Period','Subgroup','Time Period Start Date','Time Period Start Date','Time Period End Date','Low CI','High CI','Quartile Range'])
    .dropna()
    .rename(columns={"Value":"Percentage"})
)

df.drop(df[df["Indicator"] != "Symptoms of Depressive Disorder"].index, inplace=True)
df.drop(df[df["Group"] != "By State"].index, inplace=True)
df.drop(df[df["Time Period Label"] != "Sep 15 - Sep 27, 2021"].index, inplace=True)

df.reset_index(drop=True)
# Out:
#                           Indicator     Group                 State  \
# 0   Symptoms of Depressive Disorder  By State               Alabama
# 1   Symptoms of Depressive Disorder  By State                Alaska
# 2   Symptoms of Depressive Disorder  By State               Arizona
# 3   Symptoms of Depressive Disorder  By State              Arkansas
# 4   Symptoms of Depressive Disorder  By State            California
# 5   Symptoms of Depressive Disorder  By State              Colorado
# 6   Symptoms of Depressive Disorder  By State           Connecticut
# 7   Symptoms of Depressive Disorder  By State              Delaware
# 8   Symptoms of Depressive Disorder  By State  District of Columbia
# 9   Symptoms of Depressive Disorder  By State               Florida
# 10  Symptoms of Depressive Disorder  By State               Georgia
# 11  Symptoms of Depressive Disorder  By State                Hawaii
# 12  Symptoms of Depressive Disorder  By State                 Idaho
# ...

# %% [markdown]
# ### Step 2: Wrapping method chain in function

# %%
def load_and_process(url):
    df = (
        pd
        .read_csv(url)
        .drop(columns=['Phase','Time Period','Subgroup','Time Period Start Date','Time Period Start Date','Time Period End Date','Low CI','High CI','Quartile Range'])
        .dropna()
        .rename(columns={"Value":"Percentage"})
    )

    df.drop(df[df["Indicator"] != "Symptoms of Depressive Disorder"].index, inplace=True)
    df.drop(df[df["Group"] != "By State"].index, inplace=True)
    df.drop(df[df["Time Period Label"] != "Sep 15 - Sep 27, 2021"].index, inplace=True)
    
    return df.reset_index(drop=True)


load_and_process("../data/raw/Indicators_of_Anxiety_or_Depression_Based_on_Reported_Frequency_of_Symptoms_During_Last_7_Days.csv")
# Out:
#                           Indicator     Group                 State  \
# 0   Symptoms of Depressive Disorder  By State               Alabama
# 1   Symptoms of Depressive Disorder  By State                Alaska
# 2   Symptoms of Depressive Disorder  By State               Arizona
# 3   Symptoms of Depressive Disorder  By State              Arkansas
# 4   Symptoms of Depressive Disorder  By State            California
# 5   Symptoms of Depressive Disorder  By State              Colorado
# 6   Symptoms of Depressive Disorder  By State           Connecticut
# 7   Symptoms of Depressive Disorder  By State              Delaware
# 8   Symptoms of Depressive Disorder  By State  District of Columbia
# 9   Symptoms of Depressive Disorder  By State               Florida
# 10  Symptoms of Depressive Disorder  By State               Georgia
# 11  Symptoms of Depressive Disorder  By State                Hawaii
# 12  Symptoms of Depressive Disorder  By State                 Idaho
# ...

# %% [markdown]
# ### Step 3: Move the function into a new .py file

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Importing Raj's file and running her function
import project_function1
project_function1.load_and_process("../data/raw/Indicators_of_Anxiety_or_Depression_Based_on_Reported_Frequency_of_Symptoms_During_Last_7_Days.csv")
# Out:
#                        Indicator       State        Time Period Label  Value  \
# 0   Symptoms of Anxiety Disorder  California     Apr 23 - May 5, 2020   30.8
# 1   Symptoms of Anxiety Disorder  California     May 7 - May 12, 2020   31.4
# 2   Symptoms of Anxiety Disorder  California    May 14 - May 19, 2020   32.3
# 3   Symptoms of Anxiety Disorder  California    May 21 - May 26, 2020   30.4
# 4   Symptoms of Anxiety Disorder  California    May 28 - June 2, 2020   33.8
# 5   Symptoms of Anxiety Disorder  California    June 4 - June 9, 2020   33.7
# 6   Symptoms of Anxiety Disorder  California  June 11 - June 16, 2020   33.7
# 7   Symptoms of Anxiety Disorder  California  June 18 - June 23, 2020   34.4
# 8   Symptoms of Anxiety Disorder  California  June 25 - June 30, 2020   32.2
# 9   Symptoms of Anxiety Disorder  California    July 2 - July 7, 2020   32.9
# 10  Symptoms of Anxiety Disorder  California   July 9 - July 14, 2020   39.1
# ...

# %%
# Importing my file for testing
import project_functions2
project_functions2.load_and_process("../data/raw/Indicators_of_Anxiety_or_Depression_Based_on_Reported_Frequency_of_Symptoms_During_Last_7_Days.csv")
# Out:
#                           Indicator     Group                 State  \
# 0   Symptoms of Depressive Disorder  By State               Alabama
# 1   Symptoms of Depressive Disorder  By State                Alaska
# 2   Symptoms of Depressive Disorder  By State               Arizona
# 3   Symptoms of Depressive Disorder  By State              Arkansas
# 4   Symptoms of Depressive Disorder  By State            California
# 5   Symptoms of Depressive Disorder  By State              Colorado
# 6   Symptoms of Depressive Disorder  By State           Connecticut
# 7   Symptoms of Depressive Disorder  By State              Delaware
# 8   Symptoms of Depressive Disorder  By State  District of Columbia
# 9   Symptoms of Depressive Disorder  By State               Florida
# 10  Symptoms of Depressive Disorder  By State               Georgia
# 11  Symptoms of Depressive Disorder  By State                Hawaii
# 12  Symptoms of Depressive Disorder  By State                 Idaho
# ...

# %%
import project_functions2

df = project_functions.load_and_process(url_or_path_to_csv_file)
df
